# %% [markdown]
# 引入

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 读取数据

# %%
train_data = pd.read_csv('./data/train.csv')
test_data = pd.read_csv('./data/test.csv')

# %% [markdown]
# 绘制阶层统计

# %%
carrier_count = train_data['Pclass'].value_counts()
sns.set(style='darkgrid')
sns.barplot(
    x=carrier_count.index,
    y=carrier_count.values,
    alpha=0.9
)
plt.title('Frequency Distribution of pclass')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('pclass', fontsize=12)
# Out:
# Text(0.5, 0, 'pclass')

# %%
train_data['Pclass'].value_counts().head(7).plot(
    kind = 'pie',
    autopct='%1.1f%%',
    figsize=(8, 8)
).legend()

# %% [markdown]
# 绘制幸存者统计

# %%
survived_count = train_data.Survived.value_counts()
sns.set(style='darkgrid')
sns.barplot(
    x=survived_count.index,
    y=survived_count.values,
    alpha=0.9
)
plt.title('Frequency Distribution of survived')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('is survived', fontsize=12)
# Out:
# Text(0.5, 0, 'is survived')

# %%
train_data.Survived.value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(8, 8)
).legend()

# %% [markdown]
# 性别统计

# %%
train_data.Sex.value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(8, 8)
).legend()

# %% [markdown]
# 年龄最多前十统计

# %%
train_data.Age.value_counts().head(10).plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(8, 8)
).legend()

# %% [markdown]
# 登船地点统计

# %%
train_data.Embarked.value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(8, 8)
).legend()

# %%
train_data.hist(
    column=[i for i in train_data.columns if i != 'PassengerId'],
    figsize=(15, 12),
    bins=20,
    color='#107009AA'
)
# Out:
# array([[<AxesSubplot:title={'center':'Survived'}>,
#         <AxesSubplot:title={'center':'Pclass'}>],
#        [<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'SibSp'}>],
#        [<AxesSubplot:title={'center':'Parch'}>,
#         <AxesSubplot:title={'center':'Fare'}>]], dtype=object)

# %% [markdown]
# 通过生存结果数据查看相关特性

# %%
train_data.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(14, 12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(
    train_data.corr(),
    linewidths=0.1,
    vmax=1.0,
    square=True,
    cmap=colormap,
    linecolor='white',
    annot=True
)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>
